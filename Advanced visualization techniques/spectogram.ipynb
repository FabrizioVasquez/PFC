# %%
import yfinance as yf
import numpy as np
import matplotlib.pyplot as plt
tsla_df = yf.download('TSLA',
                      start='2023-01-01',
                      end='2023-07-30',
                      progress=False)
tsla_df.head()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2023-01-03  118.470001  118.800003  104.639999  108.099998  108.099998
# 2023-01-04  109.110001  114.589996  107.519997  113.639999  113.639999
# 2023-01-05  110.510002  111.750000  107.160004  110.339996  110.339996
# 2023-01-06  103.000000  114.389999  101.809998  113.059998  113.059998
# 2023-01-09  118.959999  123.519997  117.110001  119.769997  119.769997
#
#                Volume
# Date
# 2023-01-03  231402800
# 2023-01-04  180389000
# 2023-01-05  157986300
# 2023-01-06  220911100
# 2023-01-09  190284000

# %%
df = tsla_df[['Adj Close']]
df.shape
df.head()
# Out:
#              Adj Close
# Date
# 2023-01-03  108.099998
# 2023-01-04  113.639999
# 2023-01-05  110.339996
# 2023-01-06  113.059998
# 2023-01-09  119.769997

# %%
plt.figure(figsize=(18,5))
df.plot(grid=True)
plt.ylabel('Price ($)')
plt.title('Tesla Price')
# Out:
# Text(0.5, 1.0, 'Tesla Price')

# %%
plt.specgram(df, NFFT=256, Fs=2, noverlap=10, cmap='jet_r', mode='psd')
plt.colorbar()
plt.ylabel("Frequency")
plt.xlabel("days")
plt.ylim([0, 0.2])
plt.show()
# Out:
# C:\Users\jjjni\AppData\Local\Temp\ipykernel_10852\58770680.py:1: UserWarning: Only one segment is calculated since parameter NFFT (=256) >= signal length (=143).
#   plt.specgram(df, NFFT=256, Fs=2, noverlap=10, cmap='jet_r', mode='psd')
